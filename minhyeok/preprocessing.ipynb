# %%
training_set = "/home/data/data/aihub/186.복지_분야_콜센터_상담데이터/01.데이터/1.Training/03.정신건강복지센터/02.자살위기개입/"
validation_set ="/home/data/data/aihub/186.복지_분야_콜센터_상담데이터/01.데이터/2.Validation/03.정신건강복지센터/02.자살위기개입"
# Out:
# 원격 Jupyter 서버 'http://10.10.15.111:8002/'에 연결하지 못했습니다. 서버가 실행 중이고 연결할 수 있는지 확인합니다.
